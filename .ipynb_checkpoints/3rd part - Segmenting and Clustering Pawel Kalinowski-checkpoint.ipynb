# %% [markdown]
# ## Segmenting and Clustering Neighborhoods in Toronto
#
# Week 3 assignment for *pkali*, part #3

# %%
import pandas as pd
import numpy as np

# %%
from bs4 import BeautifulSoup
import requests
base = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
soup = BeautifulSoup(requests.get(base).text, 'lxml')
tabs = soup.find("table",{"class":"wikitable sortable"})
df = pd.read_html(str(tabs))[0] #read only the first tab
df.drop(df[df.Borough == 'Not assigned'].index, inplace=True)
df.reset_index(drop=True,inplace=True)

# %%
geospatial = pd.read_csv('http://cocl.us/Geospatial_data')
df = df.merge(geospatial, left_on='Postal Code', right_on='Postal Code')

# %% [markdown]
# #### Get Toronto Boroughs only

# %%
df_t = df[df.Borough.str.contains('Toronto')]

# %%
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import folium # map rendering library
address = 'Toronto, Ontario, Canada'

geolocator = Nominatim(user_agent="pkali_notebook")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_t['Latitude'], 
                                           df_t['Longitude'], 
                                           df_t['Borough'], 
                                           df_t['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)

# %% [markdown]
# #### Map of Toronto with marked neigborhoods

# %%
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX' # your Foursquare ID
CLIENT_SECRET = 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    LIMIT = 10
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=df_t['Neighborhood'],
                                   latitudes=df_t['Latitude'],
                                   longitudes=df_t['Longitude']
                                  )
# Out:
# Regent Park, Harbourfront
# Queen's Park, Ontario Provincial Government
# Garden District, Ryerson
# St. James Town
# The Beaches
# Berczy Park
# Central Bay Street
# Christie
# Richmond, Adelaide, King
# Dufferin, Dovercourt Village
# Harbourfront East, Union Station, Toronto Islands
# Little Portugal, Trinity
# The Danforth West, Riverdale
# Toronto Dominion Centre, Design Exchange
# Brockton, Parkdale Village, Exhibition Place
# India Bazaar, The Beaches West
# Commerce Court, Victoria Hotel
# Studio District
# Lawrence Park
# Roselawn
# Davisville North
# Forest Hill North & West
# High Park, The Junction South
# North Toronto West
# The Annex, North Midtown, Yorkville
# Parkdale, Roncesvalles
# Davisville
# University of Toronto, Harbord
# Runnymede, Swansea
# Moore Park, Summerhill East
# Kensington Market, Chinatown, Grange Park
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Rosedale
# Stn A PO Boxes
# St. James Town, Cabbagetown
# First Canadian Place, Underground city
# Church and Wellesley
# Business reply mail Processing Centre

# %%
toronto_venues
# Out:
#                               Neighborhood  Neighborhood Latitude  \
# 0                Regent Park, Harbourfront              43.654260
# 1                Regent Park, Harbourfront              43.654260
# 2                Regent Park, Harbourfront              43.654260
# 3                Regent Park, Harbourfront              43.654260
# 4                Regent Park, Harbourfront              43.654260
# ..                                     ...                    ...
# 347  Business reply mail Processing Centre              43.662744
# 348  Business reply mail Processing Centre              43.662744
# 349  Business reply mail Processing Centre              43.662744
# 350  Business reply mail Processing Centre              43.662744
# 351  Business reply mail Processing Centre              43.662744
#
#      Neighborhood Longitude                              Venue  \
# 0                -79.360636                   Roselle Desserts
# 1                -79.360636                      Tandem Coffee
# 2                -79.360636                 Morning Glory Cafe
# 3                -79.360636             Cooper Koo Family YMCA
# 4                -79.360636                Body Blitz Spa East
# ..                      ...                                ...
# 347              -79.321558                        Chick-n-Joy
# 348              -79.321558                     The Green Wood
# 349              -79.321558           Ashbridges Bay Skatepark
# 350              -79.321558  East End Garden Centre & Hardware
# 351              -79.321558             Amin Car Repair Garage
#
#      Venue Latitude  Venue Longitude        Venue Category
# 0         43.653447       -79.362017                Bakery
# 1         43.653559       -79.361809           Coffee Shop
# 2         43.653947       -79.361149        Breakfast Spot
# 3         43.653249       -79.358008   Distribution Center
# 4         43.654735       -79.359874                   Spa
# ..              ...              ...                   ...
# 347       43.665181       -79.321403  Fast Food Restaurant
# 348       43.664728       -79.324117            Restaurant
# 349       43.662548       -79.315631            Skate Park
# 350       43.664564       -79.324471         Garden Center
# 351       43.663544       -79.320130         Auto Workshop
#
# [352 rows x 7 columns]

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

# %% [markdown]
# #### Find most common venues in each neigborhood

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

#neighborhoods_venues_sorted.head()

# %% [markdown]
# ### Cluster neigborhoods
# Run *k*-means to cluster the neighborhood into 5 clusters, based on New York example lab.

# %%
# import k-means from clustering stage
from sklearn.cluster import KMeans

# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 

# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = df_t

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head() # check the last columns!
# Out:
#    Postal Code           Borough                                 Neighborhood  \
# 2          M5A  Downtown Toronto                    Regent Park, Harbourfront
# 4          M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 9          M5B  Downtown Toronto                     Garden District, Ryerson
# 15         M5C  Downtown Toronto                               St. James Town
# 19         M4E      East Toronto                                  The Beaches
#
#      Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 2   43.654260 -79.360636               1        Breakfast Spot
# 4   43.662301 -79.389494               4           Coffee Shop
# 9   43.657162 -79.378937               2                  Café
# 15  43.651494 -79.375418               4           Coffee Shop
# 19  43.676357 -79.293031               2                 Trail
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 2            Coffee Shop         Historic Site                  Park
# 4    Arts & Crafts Store                  Park              Creperie
# 9             Comic Shop        Clothing Store           Music Venue
# 15            Food Truck             Gastropub        Cosmetics Shop
# 19                   Pub      Asian Restaurant     Health Food Store
#
#    5th Most Common Venue 6th Most Common Venue      7th Most Common Venue  \
# 2    Distribution Center                Bakery                 Restaurant
# 4     Mexican Restaurant   Distribution Center         Italian Restaurant
# 9                Theater       Thai Restaurant                   Tea Room
# 15              Creperie            Restaurant  Middle Eastern Restaurant
# 19              Wine Bar      Department Store                    Dog Run
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 2                    Spa  Gym / Fitness Center           Dance Studio
# 4               Beer Bar     Food & Drink Shop             Food Truck
# 9                  Plaza         Burrito Place           Dance Studio
# 15   Japanese Restaurant                   Gym               Fountain
# 19   Distribution Center                 Diner           Dessert Shop

# %% [markdown]
# ### Cluster visualization

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'],
                                  toronto_merged['Longitude'],
                                  toronto_merged['Neighborhood'],
                                  toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Cluster examination
#  Examine and name all clusters.

# %% [markdown]
# #### Cluster #1

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 41     East Toronto               0      Greek Restaurant
# 62  Central Toronto               0                Garden
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 41        Ice Cream Shop           Yoga Studio        Cosmetics Shop
# 62        Ice Cream Shop          Home Service              Wine Bar
#
#       5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 41  Fruit & Vegetable Store    Italian Restaurant               Brewery
# 62             Dessert Shop            Donut Shop               Dog Run
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 41                 Diner               Dog Run    Distribution Center
# 62   Distribution Center                 Diner       Department Store

# %% [markdown]
# #### Cluster #1 name: Sweet Mediterranean Tooth

# %% [markdown]
# ----
# #### Cluster #2

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough  Cluster Labels 1st Most Common Venue  \
# 2    Downtown Toronto               1        Breakfast Spot
# 20   Downtown Toronto               1          Cocktail Bar
# 30   Downtown Toronto               1             Speakeasy
# 36   Downtown Toronto               1          Skating Rink
# 37       West Toronto               1              Wine Bar
# 47       East Toronto               1             Pet Store
# 67    Central Toronto               1                  Park
# 69       West Toronto               1             Speakeasy
# 73    Central Toronto               1           Yoga Studio
# 74    Central Toronto               1     Indian Restaurant
# 83    Central Toronto               1                  Park
# 87   Downtown Toronto               1        Airport Lounge
# 92   Downtown Toronto               1          Cocktail Bar
# 99   Downtown Toronto               1             Gastropub
# 100      East Toronto               1           Pizza Place
#
#              2nd Most Common Venue   3rd Most Common Venue  \
# 2                      Coffee Shop           Historic Site
# 20   Vegetarian / Vegan Restaurant                    Park
# 30                           Plaza                   Hotel
# 36                     Supermarket                    Park
# 37                Asian Restaurant          Ice Cream Shop
# 47                Sushi Restaurant            Liquor Store
# 67            Gym / Fitness Center          Breakfast Spot
# 69              Italian Restaurant  Furniture / Home Store
# 73                             Spa                   Diner
# 74             American Restaurant             Coffee Shop
# 83                      Restaurant             Summer Camp
# 87                         Airport      Airport Food Court
# 92                        Fountain                    Park
# 99                  Breakfast Spot            Dance Studio
# 100                  Auto Workshop    Fast Food Restaurant
#
#      4th Most Common Venue      5th Most Common Venue  \
# 2                     Park        Distribution Center
# 20             Coffee Shop               Concert Hall
# 30              Steakhouse                 Restaurant
# 36   Performing Arts Venue        Sporting Goods Shop
# 37       Korean Restaurant           Cuban Restaurant
# 47                 Brewery         Italian Restaurant
# 67          Sandwich Place                      Hotel
# 69               Gastropub                Music Venue
# 73            Dessert Shop         Mexican Restaurant
# 74                    Café  Middle Eastern Restaurant
# 83            Tennis Court        Distribution Center
# 87            Airport Gate            Airport Service
# 92              Restaurant                Tailor Shop
# 99      Mexican Restaurant           Ramen Restaurant
# 100         Farmers Market                 Comic Shop
#
#        6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 2                     Bakery            Restaurant                   Spa
# 20                  Fountain          Liquor Store                Museum
# 30      Gym / Fitness Center                  Café          Concert Hall
# 36                     Hotel                 Plaza           Salad Place
# 37   New American Restaurant          Cocktail Bar               Brewery
# 47            Ice Cream Shop  Fast Food Restaurant     Fish & Chips Shop
# 67         Food & Drink Shop      Department Store          Dance Studio
# 69                      Park                  Café   Arts & Crafts Store
# 73               Coffee Shop        Clothing Store            Restaurant
# 74              Burger Joint            Donut Shop             BBQ Joint
# 83                     Diner          Dessert Shop      Department Store
# 87          Airport Terminal              Boutique                 Plane
# 92                Food Truck          Concert Hall       Thai Restaurant
# 99                Restaurant       Bubble Tea Shop              Beer Bar
# 100            Burrito Place            Restaurant               Brewery
#
#              9th Most Common Venue         10th Most Common Venue
# 2             Gym / Fitness Center                   Dance Studio
# 20                  Farmers Market                     Restaurant
# 30   Vegetarian / Vegan Restaurant                 Cosmetics Shop
# 36                            Lake                   Dessert Shop
# 37                      Beer Store                    Pizza Place
# 47                            Park                            Gym
# 67                      Donut Shop               Cuban Restaurant
# 69                             Bar                    Flea Market
# 73              Salon / Barbershop             Chinese Restaurant
# 74                            Park  Vegetarian / Vegan Restaurant
# 83                    Dance Studio               Cuban Restaurant
# 87                 Harbor / Marina                       Wine Bar
# 92                          Museum  Vegetarian / Vegan Restaurant
# 99                            Park               Theme Restaurant
# 100                     Skate Park                  Garden Center

# %% [markdown]
# #### Cluster #2 name: Fast, fast world!

# %% [markdown]
# ----
# #### Cluster #3

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 9   Downtown Toronto               2                  Café
# 19      East Toronto               2                 Trail
# 25  Downtown Toronto               2                  Café
# 31      West Toronto               2                Bakery
# 42  Downtown Toronto               2                  Café
# 43      West Toronto               2           Coffee Shop
# 48  Downtown Toronto               2                  Café
# 54      East Toronto               2               Gay Bar
# 75      West Toronto               2             Gift Shop
# 79   Central Toronto               2    Italian Restaurant
# 80  Downtown Toronto               2           Yoga Studio
# 81      West Toronto               2    Italian Restaurant
# 84  Downtown Toronto               2                  Café
# 86   Central Toronto               2           Coffee Shop
# 96  Downtown Toronto               2                  Café
# 97  Downtown Toronto               2           Coffee Shop
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 9              Comic Shop        Clothing Store           Music Venue
# 19                    Pub      Asian Restaurant     Health Food Store
# 25          Grocery Store           Coffee Shop    Italian Restaurant
# 31            Supermarket           Music Venue               Brewery
# 42               Beer Bar  Gym / Fitness Center                   Pub
# 43                 Bakery             Pet Store                  Café
# 48            Coffee Shop                   Gym                Bakery
# 54            Fish Market             Pet Store        Sandwich Place
# 75          Movie Theater            Restaurant           Coffee Shop
# 79           Dessert Shop      Sushi Restaurant                  Café
# 80                 Bakery          Dessert Shop            Restaurant
# 81                   Food                  Café                   Pub
# 84  Vietnamese Restaurant                Bakery    Mexican Restaurant
# 86                   Bank           Supermarket            Sports Bar
# 96  General Entertainment                Bakery            Restaurant
# 97             Restaurant                  Café            Steakhouse
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 9                Theater       Thai Restaurant              Tea Room
# 19              Wine Bar      Department Store               Dog Run
# 25                 Diner           Candy Store            Restaurant
# 31                   Bar         Grocery Store                  Bank
# 42            Restaurant                Bakery              Tea Room
# 43            Restaurant                   Bar    Italian Restaurant
# 48            Restaurant                   Pub              Tea Room
# 54             Bookstore    Italian Restaurant        Ice Cream Shop
# 75    Italian Restaurant               Dog Run          Dessert Shop
# 79    Seafood Restaurant     Indian Restaurant           Pizza Place
# 80   Japanese Restaurant             Bookstore    Italian Restaurant
# 81         Burrito Place             Bookstore     Fish & Chips Shop
# 84   Arts & Crafts Store          Dessert Shop       Organic Grocery
# 86          Liquor Store   American Restaurant                   Pub
# 96                 Diner         Jewelry Store   Japanese Restaurant
# 97                   Gym  Gym / Fitness Center                Bakery
#
#           8th Most Common Venue   9th Most Common Venue 10th Most Common Venue
# 9                         Plaza           Burrito Place           Dance Studio
# 19          Distribution Center                   Diner           Dessert Shop
# 25             Department Store     Distribution Center           Dessert Shop
# 31    Middle Eastern Restaurant                    Café               Wine Bar
# 42                  Coffee Shop                     Gym    Distribution Center
# 43                          Gym  Furniture / Home Store               Fountain
# 48         Gym / Fitness Center                  Museum               Creperie
# 54                       Bakery             Coffee Shop                   Food
# 75  Eastern European Restaurant        Cuban Restaurant           Dance Studio
# 79                  Coffee Shop                    Food             Comic Shop
# 80                          Bar                Beer Bar      French Restaurant
# 81             Sushi Restaurant             Coffee Shop               Tea Room
# 84                 Dance Studio        Department Store         Farmers Market
# 86                   Restaurant        Sushi Restaurant    Distribution Center
# 96            Indian Restaurant      Italian Restaurant            Flea Market
# 97                      Dog Run     Distribution Center                  Diner

# %% [markdown]
# #### Cluster #3 name: Caffè Italiano

# %% [markdown]
# ----
# #### Cluster #4

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 61   Central Toronto               3                  Park
# 68   Central Toronto               3                  Park
# 91  Downtown Toronto               3                  Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 61              Bus Line           Swim School              Wine Bar
# 68              Bus Line      Sushi Restaurant         Jewelry Store
# 91                 Trail            Playground              Wine Bar
#
#           5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 61  Eastern European Restaurant          Concert Hall        Cosmetics Shop
# 68                        Trail          Concert Hall        Cosmetics Shop
# 91                   Donut Shop            Comic Shop          Concert Hall
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 61              Creperie      Cuban Restaurant           Dance Studio
# 68              Creperie            Donut Shop           Dance Studio
# 91        Cosmetics Shop              Creperie       Cuban Restaurant

# %% [markdown]
# #### Cluster #4 name: Walk the Dog

# %% [markdown]
# ----
# #### Cluster #5

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 4   Downtown Toronto               4           Coffee Shop
# 15  Downtown Toronto               4           Coffee Shop
# 24  Downtown Toronto               4           Coffee Shop
#
#    2nd Most Common Venue 3rd Most Common Venue       4th Most Common Venue  \
# 4    Arts & Crafts Store                  Park                    Creperie
# 15            Food Truck             Gastropub              Cosmetics Shop
# 24                   Spa             Gastropub  Modern European Restaurant
#
#         5th Most Common Venue 6th Most Common Venue  \
# 4          Mexican Restaurant   Distribution Center
# 15                   Creperie            Restaurant
# 24  Middle Eastern Restaurant       Bubble Tea Shop
#
#         7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 4          Italian Restaurant              Beer Bar     Food & Drink Shop
# 15  Middle Eastern Restaurant   Japanese Restaurant                   Gym
# 24        Japanese Restaurant            Food Truck     Food & Drink Shop
#
#    10th Most Common Venue
# 4              Food Truck
# 15               Fountain
# 24                 Garden

# %% [markdown]
# #### Cluster #5 name: Hipster's Paradise

# %%
### Map with cluster names
cluster_names = ['Sweet Mediterranean Tooth',
                 'Fast, fast world!',
                 'Caffe Italiano',
                 'Walk the Dog',
                 "Hipster's Paradise"]
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'],
                                  toronto_merged['Longitude'],
                                  toronto_merged['Neighborhood'],
                                  toronto_merged['Cluster Labels']):
    label = folium.Popup( cluster_names[cluster]+': '+str(poi), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
